# %%
import pandas as pd 
import seaborn as sns 
import matplotlib.pyplot as plt

# %%
train_data = pd.read_csv('train.tsv',encoding='utf-8',delimiter = '\t')
test_data = pd.read_csv('test.tsv',encoding = 'utf-8',delimiter = '\t')

# %%
train_data.head()
# Out:
#    id  bot  statuses_count  default_profile  default_profile_image  \
# 0   0    0             715                0                      0
# 1   2    0            2151                0                      0
# 2   3    0             439                0                      0
# 3   7    0              28                1                      0
# 4  12    0              40                0                      0
#
#    friends_count  followers_count  favourites_count  geo_enabled  \
# 0            423              206               150            1
# 1           1457             1321              1704            1
# 2            691              213                 5            0
# 3            285               31                 0            0
# 4            907               60              1013            1
#
#    listed_count  account_age_hours  diversity  mean_mins_between_tweets  \
# 0            34              36981   0.684902               3958.863636
# 1            90              35603   0.704787               2746.533708
# 2            15              38432   0.528857              11005.031847
# 3             1               4898   0.810427               6495.666667
# 4             2              47238   0.831579             112167.300000
#
#    mean_tweet_length  mean_retweets  reply_rate
# 0          97.513514       1.473684    0.504505
# 1          69.988827       3.814815    0.553073
# 2          75.101266       1.142857    0.158228
# 3          93.029412       3.000000    0.029412
# 4          79.142857       1.000000    0.047619

# %%
test_data.head()
# Out:
#    id  statuses_count  default_profile  default_profile_image  friends_count  \
# 0   1            1990                0                      0            546
# 1   4             601                0                      0            948
# 2   5              17                0                      0            301
# 3   6             271                0                      0            126
# 4   8               8                1                      0            960
#
#    followers_count  favourites_count  geo_enabled  listed_count  \
# 0             1225               133            0            53
# 1              368               212            0            32
# 2               39                 1            0             5
# 3               62                 3            0             2
# 4              146                24            0             0
#
#    account_age_hours  diversity  mean_mins_between_tweets  mean_tweet_length  \
# 0              21007   0.869048               2208.218750          90.363636
# 1              26934   0.612211                292.957143          65.829787
# 2              25497   0.879310             116383.545455          98.666667
# 3              70240   0.741379              24589.039682          75.204724
# 4              12162   0.500000                 32.428571          35.750000
#
#    mean_retweets  reply_rate
# 0            2.5    0.121212
# 1            2.0    0.609929
# 2            1.0    0.083333
# 3            3.0    0.157480
# 4            1.0    0.250000
